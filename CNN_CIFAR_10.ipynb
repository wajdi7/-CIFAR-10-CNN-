# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# One-hot encode the labels
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# Build the CNN model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))


# Set a custom learning rate (e.g., 0.001)
#custom_learning_rate = 0.001
#custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)

# Compile the model with the custom optimizer
#model.compile(optimizer=custom_optimizer, loss='categorical_crossentropy', metrics=['accuracy'])


# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#Model architecture
model.summary()
# Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')

# Make predictions on new data
predictions = model.predict(test_images[:5])
print('Predictions:', predictions.argmax(axis=1))
print('True labels:', test_labels[:5].argmax(axis=1))
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 30, 30, 32)        896
#
#  max_pooling2d_19 (MaxPooli  (None, 15, 15, 32)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 13, 13, 64)        18496
#
#  max_pooling2d_20 (MaxPooli  (None, 6, 6, 64)          0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 128)         73856
#
#  flatten_7 (Flatten)         (None, 2048)              0
#
#  dense_14 (Dense)            (None, 128)               262272
#
#  dense_15 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 356810 (1.36 MB)
# Trainable params: 356810 (1.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 625/625 [==============================] - 6s 8ms/step - loss: 1.5527 - accuracy: 0.4302 - val_loss: 1.3075 - val_accuracy: 0.5398
# Epoch 2/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.1678 - accuracy: 0.5839 - val_loss: 1.0519 - val_accuracy: 0.6285
# Epoch 3/10
# 625/625 [==============================] - 3s 5ms/step - loss: 1.0154 - accuracy: 0.6443 - val_loss: 1.0200 - val_accuracy: 0.6396
# Epoch 4/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.9070 - accuracy: 0.6814 - val_loss: 1.0365 - val_accuracy: 0.6358
# Epoch 5/10
# 625/625 [==============================] - 4s 7ms/step - loss: 0.8143 - accuracy: 0.7157 - val_loss: 0.9242 - val_accuracy: 0.6843
# Epoch 6/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.7452 - accuracy: 0.7395 - val_loss: 0.8891 - val_accuracy: 0.6916
# Epoch 7/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6780 - accuracy: 0.7616 - val_loss: 0.8713 - val_accuracy: 0.6970
# Epoch 8/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.6116 - accuracy: 0.7884 - val_loss: 0.8483 - val_accuracy: 0.7156
# Epoch 9/10
# 625/625 [==============================] - 4s 6ms/step - loss: 0.5507 - accuracy: 0.8094 - val_loss: 0.8670 - val_accuracy: 0.7167
# Epoch 10/10
# 625/625 [==============================] - 3s 5ms/step - loss: 0.4948 - accuracy: 0.8274 - val_loss: 0.8965 - val_accuracy: 0.7158
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9256 - accuracy: 0.7068
# Test accuracy: 0.7067999839782715
# 1/1 [==============================] - 0s 68ms/step
# Predictions: [3 1 8 0 4]
# True labels: [3 8 8 0 6]
